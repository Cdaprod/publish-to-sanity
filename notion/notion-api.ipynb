# %% [markdown]
# # Converting Notion API Data to Portable Text for the Sanity.io Dataset
# ##### By Cdaprod (David Cannan)
# ##### November 19, 2024
# ## Prerequsite Step:
# ### Generate JSON Log for Persistence needed later

# %%
import json
import os

# File path for storing the progress log
PROGRESS_LOG_FILE = 'notion_progress_log.json'

# Load existing progress log or create a new one if it doesn't exist
if os.path.exists(PROGRESS_LOG_FILE):
    with open(PROGRESS_LOG_FILE, 'r') as file:
        processed_pages = json.load(file)
else:
    processed_pages = []

print(f"Loaded progress log. Number of pages already processed: {len(processed_pages)}")
# Out:
# Loaded progress log. Number of pages already processed: 1

# %% [markdown]
# ## Setup Environment Variables and Notion Client

# %%
# Import necessary libraries
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Get Notion API token and Database ID from environment variables
NOTION_INTEGRATION_TOKEN = os.getenv('NOTION_INTEGRATION_TOKEN')
NOTION_DATABASE_ID = os.getenv('NOTION_DATABASE_ID')

# Ensure environment variables are loaded
if not NOTION_INTEGRATION_TOKEN or not NOTION_DATABASE_ID:
    raise EnvironmentError("Please set NOTION_INTEGRATION_TOKEN and NOTION_DATABASE_ID in the .env file")

# %%
# Import the Notion client
from notion_client import Client

# Initialize the Notion client
notion = Client(auth=NOTION_INTEGRATION_TOKEN)

# Confirm that the client is initialized
print("Notion client initialized successfully")
# Out:
# Notion client initialized successfully

# %% [markdown]
# # Inspect the database connection

# %%
# Function to fetch and print pages from a Notion database
def fetch_notion_database(database_id):
    response = notion.databases.query(database_id=database_id)
    return response['results']

# Fetch and display results from the Notion database
try:
    notion_pages = fetch_notion_database(NOTION_DATABASE_ID)
    if notion_pages:
        print(f"Number of pages found: {len(notion_pages)}")
        for page in notion_pages:
            print(page)  # Print each page's details
    else:
        print("No pages found in the database.")
except Exception as e:
    print(f"Error fetching Notion database: {e}")
# Out:
# Number of pages found: 100
# {'object': 'page', 'id': '14390ef7-bebc-80da-990c-ee3e541444d2', 'created_time': '2024-11-19T20:28:00.000Z', 'last_edited_time': '2024-11-19T21:56:00.000Z', 'created_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'cover': None, 'icon': {'type': 'emoji', 'emoji': '📹'}, 'parent': {'type': 'database_id', 'database_id': '371d24c0-59fd-4622-a0b7-fa8369bbede8'}, 'archived': False, 'in_trash': False, 'properties': {'Created time': {'id': 'EOiB', 'type': 'created_time', 'created_time': '2024-11-19T20:28:00.000Z'}, 'Last edited by': {'id': 'MNQk', 'type': 'last_edited_by', 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5', 'name': 'David Cannan', 'avatar_url': 'https://lh3.googleusercontent.com/a-/AFdZucpV9CJe58bbkJi0GMZiBz9zgA-FyjhTzsemCkJy488=s100', 'type': 'person', 'person': {'email': 'davidacannan@gmail.com'}}}, 'Last edited time': {'id': 'YwON', 'type': 'last_edited_time', 'last_edited_time': '2024-11-19T21:56:00.000Z'}, 'Tags': {'id': 'prUH', 'type': 'multi_select', 'multi_select': []}, 'ID': {'id': 'r%3DxR', 'type': 'unique_id', 'unique_id': {'prefix': 'BP', 'number': 160}}, 'Title': {'id': 'wZ%7B%7D', 'type': 'rich_text', 'rich_text': []}, 'Name': {'id': 'title', 'type': 'title', 'title': [{'type': 'text', 'text': {'content': 'Raspberry Pi Cluster', 'link': None}, 'annotations': {'bold': False, 'italic': False, 'strikethrough': False, 'underline': False, 'code': False, 'color': 'default'}, 'plain_text': 'Raspberry Pi Cluster', 'href': None}]}, 'Status': {'id': 'a0c960ca-30de-46df-8bc6-0d8f1c2e1b2b', 'type': 'status', 'status': {'id': 'bae1b841-a999-478a-b25a-f0f88fcebc08', 'name': 'Not started', 'color': 'default'}}}, 'url': 'https://www.notion.so/Raspberry-Pi-Cluster-14390ef7bebc80da990cee3e541444d2', 'public_url': 'https://davidcannan.notion.site/Raspberry-Pi-Cluster-14390ef7bebc80da990cee3e541444d2'}
# {'object': 'page', 'id': '9efd2c63-9975-470f-bdb9-4cfe0de5584a', 'created_time': '2024-11-19T18:30:00.000Z', 'last_edited_time': '2024-11-19T18:31:00.000Z', 'created_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'cover': None, 'icon': {'type': 'emoji', 'emoji': '📘'}, 'parent': {'type': 'database_id', 'database_id': '371d24c0-59fd-4622-a0b7-fa8369bbede8'}, 'archived': False, 'in_trash': False, 'properties': {'Created time': {'id': 'EOiB', 'type': 'created_time', 'created_time': '2024-11-19T18:30:00.000Z'}, 'Last edited by': {'id': 'MNQk', 'type': 'last_edited_by', 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5', 'name': 'David Cannan', 'avatar_url': 'https://lh3.googleusercontent.com/a-/AFdZucpV9CJe58bbkJi0GMZiBz9zgA-FyjhTzsemCkJy488=s100', 'type': 'person', 'person': {'email': 'davidacannan@gmail.com'}}}, 'Last edited time': {'id': 'YwON', 'type': 'last_edited_time', 'last_edited_time': '2024-11-19T18:31:00.000Z'}, 'Tags': {'id': 'prUH', 'type': 'multi_select', 'multi_select': []}, 'ID': {'id': 'r%3DxR', 'type': 'unique_id', 'unique_id': {'prefix': 'BP', 'number': 159}}, 'Title': {'id': 'wZ%7B%7D', 'type': 'rich_text', 'rich_text': []}, 'Name': {'id': 'title', 'type': 'title', 'title': [{'type': 'text', 'text': {'content': 'Mastering Emotional Detachment: Nurturing Relationships Without Losing Yourself', 'link': None}, 'annotations': {'bold': False, 'italic': False, 'strikethrough': False, 'underline': False, 'code': False, 'color': 'default'}, 'plain_text': 'Mastering Emotional Detachment: Nurturing Relationships Without Losing Yourself', 'href': None}]}, 'Status': {'id': 'a0c960ca-30de-46df-8bc6-0d8f1c2e1b2b', 'type': 'status', 'status': {'id': 'bae1b841-a999-478a-b25a-f0f88fcebc08', 'name': 'Not started', 'color': 'default'}}}, 'url': 'https://www.notion.so/Mastering-Emotional-Detachment-Nurturing-Relationships-Without-Losing-Yourself-9efd2c639975470fbdb94cfe0de5584a', 'public_url': 'https://davidcannan.notion.site/Mastering-Emotional-Detachment-Nurturing-Relationships-Without-Losing-Yourself-9efd2c639975470fbdb94cfe0de5584a'}
# {'object': 'page', 'id': '14290ef7-bebc-80a7-9043-e14c32c8a64d', 'created_time': '2024-11-18T22:15:00.000Z', 'last_edited_time': '2024-11-18T22:16:00.000Z', 'created_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'cover': None, 'icon': {'type': 'emoji', 'emoji': '📗'}, 'parent': {'type': 'database_id', 'database_id': '371d24c0-59fd-4622-a0b7-fa8369bbede8'}, 'archived': False, 'in_trash': False, 'properties': {'Created time': {'id': 'EOiB', 'type': 'created_time', 'created_time': '2024-11-18T22:15:00.000Z'}, 'Last edited by': {'id': 'MNQk', 'type': 'last_edited_by', 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5', 'name': 'David Cannan', 'avatar_url': 'https://lh3.googleusercontent.com/a-/AFdZucpV9CJe58bbkJi0GMZiBz9zgA-FyjhTzsemCkJy488=s100', 'type': 'person', 'person': {'email': 'davidacannan@gmail.com'}}}, 'Last edited time': {'id': 'YwON', 'type': 'last_edited_time', 'last_edited_time': '2024-11-18T22:16:00.000Z'}, 'Tags': {'id': 'prUH', 'type': 'multi_select', 'multi_select': []}, 'ID': {'id': 'r%3DxR', 'type': 'unique_id', 'unique_id': {'prefix': 'BP', 'number': 158}}, 'Title': {'id': 'wZ%7B%7D', 'type': 'rich_text', 'rich_text': []}, 'Name': {'id': 'title', 'type': 'title', 'title': [{'type': 'text', 'text': {'content': 'Sanity Blog Registry Clap Back 👏\xa0', 'link': None}, 'annotations': {'bold': False, 'italic': False, 'strikethrough': False, 'underline': False, 'code': False, 'color': 'default'}, 'plain_text': 'Sanity Blog Registry Clap Back 👏\xa0', 'href': None}]}, 'Status': {'id': 'a0c960ca-30de-46df-8bc6-0d8f1c2e1b2b', 'type': 'status', 'status': {'id': 'bae1b841-a999-478a-b25a-f0f88fcebc08', 'name': 'Not started', 'color': 'default'}}}, 'url': 'https://www.notion.so/Sanity-Blog-Registry-Clap-Back-14290ef7bebc80a79043e14c32c8a64d', 'public_url': 'https://davidcannan.notion.site/Sanity-Blog-Registry-Clap-Back-14290ef7bebc80a79043e14c32c8a64d'}
# {'object': 'page', 'id': '14290ef7-bebc-80b2-87fe-cb968e8705d9', 'created_time': '2024-11-18T01:27:00.000Z', 'last_edited_time': '2024-11-18T02:08:00.000Z', 'created_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'cover': None, 'icon': {'type': 'emoji', 'emoji': '📗'}, 'parent': {'type': 'database_id', 'database_id': '371d24c0-59fd-4622-a0b7-fa8369bbede8'}, 'archived': False, 'in_trash': False, 'properties': {'Created time': {'id': 'EOiB', 'type': 'created_time', 'created_time': '2024-11-18T01:27:00.000Z'}, 'Last edited by': {'id': 'MNQk', 'type': 'last_edited_by', 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5', 'name': 'David Cannan', 'avatar_url': 'https://lh3.googleusercontent.com/a-/AFdZucpV9CJe58bbkJi0GMZiBz9zgA-FyjhTzsemCkJy488=s100', 'type': 'person', 'person': {'email': 'davidacannan@gmail.com'}}}, 'Last edited time': {'id': 'YwON', 'type': 'last_edited_time', 'last_edited_time': '2024-11-18T02:08:00.000Z'}, 'Tags': {'id': 'prUH', 'type': 'multi_select', 'multi_select': []}, 'ID': {'id': 'r%3DxR', 'type': 'unique_id', 'unique_id': {'prefix': 'BP', 'number': 157}}, 'Title': {'id': 'wZ%7B%7D', 'type': 'rich_text', 'rich_text': []}, 'Name': {'id': 'title', 'type': 'title', 'title': [{'type': 'text', 'text': {'content': 'Guide to Focus', 'link': None}, 'annotations': {'bold': False, 'italic': False, 'strikethrough': False, 'underline': False, 'code': False, 'color': 'default'}, 'plain_text': 'Guide to Focus', 'href': None}]}, 'Status': {'id': 'a0c960ca-30de-46df-8bc6-0d8f1c2e1b2b', 'type': 'status', 'status': {'id': 'bae1b841-a999-478a-b25a-f0f88fcebc08', 'name': 'Not started', 'color': 'default'}}}, 'url': 'https://www.notion.so/Guide-to-Focus-14290ef7bebc80b287fecb968e8705d9', 'public_url': 'https://davidcannan.notion.site/Guide-to-Focus-14290ef7bebc80b287fecb968e8705d9'}
# {'object': 'page', 'id': '14190ef7-bebc-80b5-9010-ea88777c4c4d', 'created_time': '2024-11-17T19:34:00.000Z', 'last_edited_time': '2024-11-17T19:36:00.000Z', 'created_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'cover': None, 'icon': {'type': 'emoji', 'emoji': '📗'}, 'parent': {'type': 'database_id', 'database_id': '371d24c0-59fd-4622-a0b7-fa8369bbede8'}, 'archived': False, 'in_trash': False, 'properties': {'Created time': {'id': 'EOiB', 'type': 'created_time', 'created_time': '2024-11-17T19:34:00.000Z'}, 'Last edited by': {'id': 'MNQk', 'type': 'last_edited_by', 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5', 'name': 'David Cannan', 'avatar_url': 'https://lh3.googleusercontent.com/a-/AFdZucpV9CJe58bbkJi0GMZiBz9zgA-FyjhTzsemCkJy488=s100', 'type': 'person', 'person': {'email': 'davidacannan@gmail.com'}}}, 'Last edited time': {'id': 'YwON', 'type': 'last_edited_time', 'last_edited_time': '2024-11-17T19:36:00.000Z'}, 'Tags': {'id': 'prUH', 'type': 'multi_select', 'multi_select': []}, 'ID': {'id': 'r%3DxR', 'type': 'unique_id', 'unique_id': {'prefix': 'BP', 'number': 156}}, 'Title': {'id': 'wZ%7B%7D', 'type': 'rich_text', 'rich_text': []}, 'Name': {'id': 'title', 'type': 'title', 'title': [{'type': 'text', 'text': {'content': 'Hash Tables and Hashing in Data Structures and Algorithms (DSA)', 'link': None}, 'annotations': {'bold': True, 'italic': False, 'strikethrough': False, 'underline': False, 'code': False, 'color': 'default'}, 'plain_text': 'Hash Tables and Hashing in Data Structures and Algorithms (DSA)', 'href': None}]}, 'Status': {'id': 'a0c960ca-30de-46df-8bc6-0d8f1c2e1b2b', 'type': 'status', 'status': {'id': 'bae1b841-a999-478a-b25a-f0f88fcebc08', 'name': 'Not started', 'color': 'default'}}}, 'url': 'https://www.notion.so/Hash-Tables-and-Hashing-in-Data-Structures-and-Algorithms-DSA-14190ef7bebc80b59010ea88777c4c4d', 'public_url': 'https://davidcannan.notion.site/Hash-Tables-and-Hashing-in-Data-Structures-and-Algorithms-DSA-14190ef7bebc80b59010ea88777c4c4d'}
# {'object': 'page', 'id': '14090ef7-bebc-8027-8209-ebc86820299e', 'created_time': '2024-11-16T02:04:00.000Z', 'last_edited_time': '2024-11-19T21:57:00.000Z', 'created_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'cover': None, 'icon': {'type': 'emoji', 'emoji': '📗'}, 'parent': {'type': 'database_id', 'database_id': '371d24c0-59fd-4622-a0b7-fa8369bbede8'}, 'archived': False, 'in_trash': False, 'properties': {'Created time': {'id': 'EOiB', 'type': 'created_time', 'created_time': '2024-11-16T02:04:00.000Z'}, 'Last edited by': {'id': 'MNQk', 'type': 'last_edited_by', 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5', 'name': 'David Cannan', 'avatar_url': 'https://lh3.googleusercontent.com/a-/AFdZucpV9CJe58bbkJi0GMZiBz9zgA-FyjhTzsemCkJy488=s100', 'type': 'person', 'person': {'email': 'davidacannan@gmail.com'}}}, 'Last edited time': {'id': 'YwON', 'type': 'last_edited_time', 'last_edited_time': '2024-11-19T21:57:00.000Z'}, 'Tags': {'id': 'prUH', 'type': 'multi_select', 'multi_select': [{'id': 'b9e47259-0961-4463-a783-a9d69e3253c5', 'name': 'Sanity Dataset', 'color': 'gray'}]}, 'ID': {'id': 'r%3DxR', 'type': 'unique_id', 'unique_id': {'prefix': 'BP', 'number': 155}}, 'Title': {'id': 'wZ%7B%7D', 'type': 'rich_text', 'rich_text': []}, 'Name': {'id': 'title', 'type': 'title', 'title': [{'type': 'text', 'text': {'content': 'Why Mastering Emotional Detachment is a Good Thing for Connection', 'link': None}, 'annotations': {'bold': False, 'italic': False, 'strikethrough': False, 'underline': False, 'code': False, 'color': 'default'}, 'plain_text': 'Why Mastering Emotional Detachment is a Good Thing for Connection', 'href': None}]}, 'Status': {'id': 'a0c960ca-30de-46df-8bc6-0d8f1c2e1b2b', 'type': 'status', 'status': {'id': 'bae1b841-a999-478a-b25a-f0f88fcebc08', 'name': 'Not started', 'color': 'default'}}}, 'url': 'https://www.notion.so/Why-Mastering-Emotional-Detachment-is-a-Good-Thing-for-Connection-14090ef7bebc80278209ebc86820299e', 'public_url': 'https://davidcannan.notion.site/Why-Mastering-Emotional-Detachment-is-a-Good-Thing-for-Connection-14090ef7bebc80278209ebc86820299e'}
# {'object': 'page', 'id': '13c90ef7-bebc-802f-bdd5-e15910f6238a', 'created_time': '2024-11-12T23:49:00.000Z', 'last_edited_time': '2024-11-12T23:51:00.000Z', 'created_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'cover': None, 'icon': {'type': 'emoji', 'emoji': '📗'}, 'parent': {'type': 'database_id', 'database_id': '371d24c0-59fd-4622-a0b7-fa8369bbede8'}, 'archived': False, 'in_trash': False, 'properties': {'Created time': {'id': 'EOiB', 'type': 'created_time', 'created_time': '2024-11-12T23:49:00.000Z'}, 'Last edited by': {'id': 'MNQk', 'type': 'last_edited_by', 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5', 'name': 'David Cannan', 'avatar_url': 'https://lh3.googleusercontent.com/a-/AFdZucpV9CJe58bbkJi0GMZiBz9zgA-FyjhTzsemCkJy488=s100', 'type': 'person', 'person': {'email': 'davidacannan@gmail.com'}}}, 'Last edited time': {'id': 'YwON', 'type': 'last_edited_time', 'last_edited_time': '2024-11-12T23:51:00.000Z'}, 'Tags': {'id': 'prUH', 'type': 'multi_select', 'multi_select': []}, 'ID': {'id': 'r%3DxR', 'type': 'unique_id', 'unique_id': {'prefix': 'BP', 'number': 154}}, 'Title': {'id': 'wZ%7B%7D', 'type': 'rich_text', 'rich_text': []}, 'Name': {'id': 'title', 'type': 'title', 'title': [{'type': 'text', 'text': {'content': 'What’s an Edge Case in Problem Solving', 'link': None}, 'annotations': {'bold': False, 'italic': False, 'strikethrough': False, 'underline': False, 'code': False, 'color': 'default'}, 'plain_text': 'What’s an Edge Case in Problem Solving', 'href': None}]}, 'Status': {'id': 'a0c960ca-30de-46df-8bc6-0d8f1c2e1b2b', 'type': 'status', 'status': {'id': 'bae1b841-a999-478a-b25a-f0f88fcebc08', 'name': 'Not started', 'color': 'default'}}}, 'url': 'https://www.notion.so/What-s-an-Edge-Case-in-Problem-Solving-13c90ef7bebc802fbdd5e15910f6238a', 'public_url': 'https://davidcannan.notion.site/What-s-an-Edge-Case-in-Problem-Solving-13c90ef7bebc802fbdd5e15910f6238a'}
# {'object': 'page', 'id': '13b90ef7-bebc-802a-ab17-e1fa4244f1e0', 'created_time': '2024-11-11T03:06:00.000Z', 'last_edited_time': '2024-11-11T03:07:00.000Z', 'created_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'cover': None, 'icon': {'type': 'emoji', 'emoji': '📗'}, 'parent': {'type': 'database_id', 'database_id': '371d24c0-59fd-4622-a0b7-fa8369bbede8'}, 'archived': False, 'in_trash': False, 'properties': {'Created time': {'id': 'EOiB', 'type': 'created_time', 'created_time': '2024-11-11T03:06:00.000Z'}, 'Last edited by': {'id': 'MNQk', 'type': 'last_edited_by', 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5', 'name': 'David Cannan', 'avatar_url': 'https://lh3.googleusercontent.com/a-/AFdZucpV9CJe58bbkJi0GMZiBz9zgA-FyjhTzsemCkJy488=s100', 'type': 'person', 'person': {'email': 'davidacannan@gmail.com'}}}, 'Last edited time': {'id': 'YwON', 'type': 'last_edited_time', 'last_edited_time': '2024-11-11T03:07:00.000Z'}, 'Tags': {'id': 'prUH', 'type': 'multi_select', 'multi_select': []}, 'ID': {'id': 'r%3DxR', 'type': 'unique_id', 'unique_id': {'prefix': 'BP', 'number': 153}}, 'Title': {'id': 'wZ%7B%7D', 'type': 'rich_text', 'rich_text': []}, 'Name': {'id': 'title', 'type': 'title', 'title': [{'type': 'text', 'text': {'content': 'David’s 10 Year Guide to Starting Fresh and being Successful ', 'link': None}, 'annotations': {'bold': False, 'italic': False, 'strikethrough': False, 'underline': False, 'code': False, 'color': 'default'}, 'plain_text': 'David’s 10 Year Guide to Starting Fresh and being Successful ', 'href': None}]}, 'Status': {'id': 'a0c960ca-30de-46df-8bc6-0d8f1c2e1b2b', 'type': 'status', 'status': {'id': 'bae1b841-a999-478a-b25a-f0f88fcebc08', 'name': 'Not started', 'color': 'default'}}}, 'url': 'https://www.notion.so/David-s-10-Year-Guide-to-Starting-Fresh-and-being-Successful-13b90ef7bebc802aab17e1fa4244f1e0', 'public_url': 'https://davidcannan.notion.site/David-s-10-Year-Guide-to-Starting-Fresh-and-being-Successful-13b90ef7bebc802aab17e1fa4244f1e0'}
# {'object': 'page', 'id': '13690ef7-bebc-80dc-a927-ec4204300520', 'created_time': '2024-11-06T18:42:00.000Z', 'last_edited_time': '2024-11-06T20:26:00.000Z', 'created_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'cover': None, 'icon': {'type': 'emoji', 'emoji': '📗'}, 'parent': {'type': 'database_id', 'database_id': '371d24c0-59fd-4622-a0b7-fa8369bbede8'}, 'archived': False, 'in_trash': False, 'properties': {'Created time': {'id': 'EOiB', 'type': 'created_time', 'created_time': '2024-11-06T18:42:00.000Z'}, 'Last edited by': {'id': 'MNQk', 'type': 'last_edited_by', 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5', 'name': 'David Cannan', 'avatar_url': 'https://lh3.googleusercontent.com/a-/AFdZucpV9CJe58bbkJi0GMZiBz9zgA-FyjhTzsemCkJy488=s100', 'type': 'person', 'person': {'email': 'davidacannan@gmail.com'}}}, 'Last edited time': {'id': 'YwON', 'type': 'last_edited_time', 'last_edited_time': '2024-11-06T20:26:00.000Z'}, 'Tags': {'id': 'prUH', 'type': 'multi_select', 'multi_select': []}, 'ID': {'id': 'r%3DxR', 'type': 'unique_id', 'unique_id': {'prefix': 'BP', 'number': 152}}, 'Title': {'id': 'wZ%7B%7D', 'type': 'rich_text', 'rich_text': []}, 'Name': {'id': 'title', 'type': 'title', 'title': [{'type': 'text', 'text': {'content': 'Learn Go Through Real Questions ', 'link': None}, 'annotations': {'bold': False, 'italic': False, 'strikethrough': False, 'underline': False, 'code': False, 'color': 'default'}, 'plain_text': 'Learn Go Through Real Questions ', 'href': None}]}, 'Status': {'id': 'a0c960ca-30de-46df-8bc6-0d8f1c2e1b2b', 'type': 'status', 'status': {'id': 'bae1b841-a999-478a-b25a-f0f88fcebc08', 'name': 'Not started', 'color': 'default'}}}, 'url': 'https://www.notion.so/Learn-Go-Through-Real-Questions-13690ef7bebc80dca927ec4204300520', 'public_url': 'https://davidcannan.notion.site/Learn-Go-Through-Real-Questions-13690ef7bebc80dca927ec4204300520'}
# {'object': 'page', 'id': '13690ef7-bebc-800b-bdbd-cfc049ce13ed', 'created_time': '2024-11-06T18:13:00.000Z', 'last_edited_time': '2024-11-06T18:41:00.000Z', 'created_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'cover': None, 'icon': {'type': 'emoji', 'emoji': '📗'}, 'parent': {'type': 'database_id', 'database_id': '371d24c0-59fd-4622-a0b7-fa8369bbede8'}, 'archived': False, 'in_trash': False, 'properties': {'Created time': {'id': 'EOiB', 'type': 'created_time', 'created_time': '2024-11-06T18:13:00.000Z'}, 'Last edited by': {'id': 'MNQk', 'type': 'last_edited_by', 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5', 'name': 'David Cannan', 'avatar_url': 'https://lh3.googleusercontent.com/a-/AFdZucpV9CJe58bbkJi0GMZiBz9zgA-FyjhTzsemCkJy488=s100', 'type': 'person', 'person': {'email': 'davidacannan@gmail.com'}}}, 'Last edited time': {'id': 'YwON', 'type': 'last_edited_time', 'last_edited_time': '2024-11-06T18:41:00.000Z'}, 'Tags': {'id': 'prUH', 'type': 'multi_select', 'multi_select': []}, 'ID': {'id': 'r%3DxR', 'type': 'unique_id', 'unique_id': {'prefix': 'BP', 'number': 151}}, 'Title': {'id': 'wZ%7B%7D', 'type': 'rich_text', 'rich_text': []}, 'Name': {'id': 'title', 'type': 'title', 'title': [{'type': 'text', 'text': {'content': 'RTMP Golang Project', 'link': None}, 'annotations': {'bold': False, 'italic': False, 'strikethrough': False, 'underline': False, 'code': False, 'color': 'default'}, 'plain_text': 'RTMP Golang Project', 'href': None}]}, 'Status': {'id': 'a0c960ca-30de-46df-8bc6-0d8f1c2e1b2b', 'type': 'status', 'status': {'id': 'bae1b841-a999-478a-b25a-f0f88fcebc08', 'name': 'Not started', 'color': 'default'}}}, 'url': 'https://www.notion.so/RTMP-Golang-Project-13690ef7bebc800bbdbdcfc049ce13ed', 'public_url': 'https://davidcannan.notion.site/RTMP-Golang-Project-13690ef7bebc800bbdbdcfc049ce13ed'}
# {'object': 'page', 'id': '12f90ef7-bebc-80d3-be38-c343026902f2', 'created_time': '2024-10-30T19:17:00.000Z', 'last_edited_time': '2024-10-30T19:17:00.000Z', 'created_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'cover': None, 'icon': {'type': 'emoji', 'emoji': '📗'}, 'parent': {'type': 'database_id', 'database_id': '371d24c0-59fd-4622-a0b7-fa8369bbede8'}, 'archived': False, 'in_trash': False, 'properties': {'Created time': {'id': 'EOiB', 'type': 'created_time', 'created_time': '2024-10-30T19:17:00.000Z'}, 'Last edited by': {'id': 'MNQk', 'type': 'last_edited_by', 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5', 'name': 'David Cannan', 'avatar_url': 'https://lh3.googleusercontent.com/a-/AFdZucpV9CJe58bbkJi0GMZiBz9zgA-FyjhTzsemCkJy488=s100', 'type': 'person', 'person': {'email': 'davidacannan@gmail.com'}}}, 'Last edited time': {'id': 'YwON', 'type': 'last_edited_time', 'last_edited_time': '2024-10-30T19:17:00.000Z'}, 'Tags': {'id': 'prUH', 'type': 'multi_select', 'multi_select': []}, 'ID': {'id': 'r%3DxR', 'type': 'unique_id', 'unique_id': {'prefix': 'BP', 'number': 150}}, 'Title': {'id': 'wZ%7B%7D', 'type': 'rich_text', 'rich_text': []}, 'Name': {'id': 'title', 'type': 'title', 'title': [{'type': 'text', 'text': {'content': 'From Service to Micro Service', 'link': None}, 'annotations': {'bold': False, 'italic': False, 'strikethrough': False, 'underline': False, 'code': False, 'color': 'default'}, 'plain_text': 'From Service to Micro Service', 'href': None}]}, 'Status': {'id': 'a0c960ca-30de-46df-8bc6-0d8f1c2e1b2b', 'type': 'status', 'status': {'id': 'bae1b841-a999-478a-b25a-f0f88fcebc08', 'name': 'Not started', 'color': 'default'}}}, 'url': 'https://www.notion.so/From-Service-to-Micro-Service-12f90ef7bebc80d3be38c343026902f2', 'public_url': 'https://davidcannan.notion.site/From-Service-to-Micro-Service-12f90ef7bebc80d3be38c343026902f2'}
# {'object': 'page', 'id': '12f90ef7-bebc-808b-8e49-e038e1488a75', 'created_time': '2024-10-30T19:17:00.000Z', 'last_edited_time': '2024-10-30T19:17:00.000Z', 'created_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'cover': None, 'icon': {'type': 'emoji', 'emoji': '📗'}, 'parent': {'type': 'database_id', 'database_id': '371d24c0-59fd-4622-a0b7-fa8369bbede8'}, 'archived': False, 'in_trash': False, 'properties': {'Created time': {'id': 'EOiB', 'type': 'created_time', 'created_time': '2024-10-30T19:17:00.000Z'}, 'Last edited by': {'id': 'MNQk', 'type': 'last_edited_by', 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5', 'name': 'David Cannan', 'avatar_url': 'https://lh3.googleusercontent.com/a-/AFdZucpV9CJe58bbkJi0GMZiBz9zgA-FyjhTzsemCkJy488=s100', 'type': 'person', 'person': {'email': 'davidacannan@gmail.com'}}}, 'Last edited time': {'id': 'YwON', 'type': 'last_edited_time', 'last_edited_time': '2024-10-30T19:17:00.000Z'}, 'Tags': {'id': 'prUH', 'type': 'multi_select', 'multi_select': []}, 'ID': {'id': 'r%3DxR', 'type': 'unique_id', 'unique_id': {'prefix': 'BP', 'number': 149}}, 'Title': {'id': 'wZ%7B%7D', 'type': 'rich_text', 'rich_text': []}, 'Name': {'id': 'title', 'type': 'title', 'title': [{'type': 'text', 'text': {'content': 'BlogPost ', 'link': None}, 'annotations': {'bold': False, 'italic': False, 'strikethrough': False, 'underline': False, 'code': False, 'color': 'default'}, 'plain_text': 'BlogPost ', 'href': None}]}, 'Status': {'id': 'a0c960ca-30de-46df-8bc6-0d8f1c2e1b2b', 'type': 'status', 'status': {'id': 'bae1b841-a999-478a-b25a-f0f88fcebc08', 'name': 'Not started', 'color': 'default'}}}, 'url': 'https://www.notion.so/BlogPost-12f90ef7bebc808b8e49e038e1488a75', 'public_url': 'https://davidcannan.notion.site/BlogPost-12f90ef7bebc808b8e49e038e1488a75'}
# {'object': 'page', 'id': '12f90ef7-bebc-8071-9a32-dc8d1c183764', 'created_time': '2024-10-30T18:59:00.000Z', 'last_edited_time': '2024-10-30T19:11:00.000Z', 'created_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'cover': None, 'icon': {'type': 'emoji', 'emoji': '📗'}, 'parent': {'type': 'database_id', 'database_id': '371d24c0-59fd-4622-a0b7-fa8369bbede8'}, 'archived': False, 'in_trash': False, 'properties': {'Created time': {'id': 'EOiB', 'type': 'created_time', 'created_time': '2024-10-30T18:59:00.000Z'}, 'Last edited by': {'id': 'MNQk', 'type': 'last_edited_by', 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5', 'name': 'David Cannan', 'avatar_url': 'https://lh3.googleusercontent.com/a-/AFdZucpV9CJe58bbkJi0GMZiBz9zgA-FyjhTzsemCkJy488=s100', 'type': 'person', 'person': {'email': 'davidacannan@gmail.com'}}}, 'Last edited time': {'id': 'YwON', 'type': 'last_edited_time', 'last_edited_time': '2024-10-30T19:11:00.000Z'}, 'Tags': {'id': 'prUH', 'type': 'multi_select', 'multi_select': []}, 'ID': {'id': 'r%3DxR', 'type': 'unique_id', 'unique_id': {'prefix': 'BP', 'number': 148}}, 'Title': {'id': 'wZ%7B%7D', 'type': 'rich_text', 'rich_text': []}, 'Name': {'id': 'title', 'type': 'title', 'title': [{'type': 'text', 'text': {'content': 'Designing a Principled Registry', 'link': None}, 'annotations': {'bold': False, 'italic': False, 'strikethrough': False, 'underline': False, 'code': False, 'color': 'default'}, 'plain_text': 'Designing a Principled Registry', 'href': None}]}, 'Status': {'id': 'a0c960ca-30de-46df-8bc6-0d8f1c2e1b2b', 'type': 'status', 'status': {'id': 'bae1b841-a999-478a-b25a-f0f88fcebc08', 'name': 'Not started', 'color': 'default'}}}, 'url': 'https://www.notion.so/Designing-a-Principled-Registry-12f90ef7bebc80719a32dc8d1c183764', 'public_url': 'https://davidcannan.notion.site/Designing-a-Principled-Registry-12f90ef7bebc80719a32dc8d1c183764'}
# {'object': 'page', 'id': '12f90ef7-bebc-8016-90b5-d77cc689dbe5', 'created_time': '2024-10-30T18:00:00.000Z', 'last_edited_time': '2024-10-30T18:01:00.000Z', 'created_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'cover': None, 'icon': {'type': 'emoji', 'emoji': '📗'}, 'parent': {'type': 'database_id', 'database_id': '371d24c0-59fd-4622-a0b7-fa8369bbede8'}, 'archived': False, 'in_trash': False, 'properties': {'Created time': {'id': 'EOiB', 'type': 'created_time', 'created_time': '2024-10-30T18:00:00.000Z'}, 'Last edited by': {'id': 'MNQk', 'type': 'last_edited_by', 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5', 'name': 'David Cannan', 'avatar_url': 'https://lh3.googleusercontent.com/a-/AFdZucpV9CJe58bbkJi0GMZiBz9zgA-FyjhTzsemCkJy488=s100', 'type': 'person', 'person': {'email': 'davidacannan@gmail.com'}}}, 'Last edited time': {'id': 'YwON', 'type': 'last_edited_time', 'last_edited_time': '2024-10-30T18:01:00.000Z'}, 'Tags': {'id': 'prUH', 'type': 'multi_select', 'multi_select': []}, 'ID': {'id': 'r%3DxR', 'type': 'unique_id', 'unique_id': {'prefix': 'BP', 'number': 147}}, 'Title': {'id': 'wZ%7B%7D', 'type': 'rich_text', 'rich_text': []}, 'Name': {'id': 'title', 'type': 'title', 'title': [{'type': 'text', 'text': {'content': 'Go-Kube-Compiler', 'link': None}, 'annotations': {'bold': False, 'italic': False, 'strikethrough': False, 'underline': False, 'code': False, 'color': 'default'}, 'plain_text': 'Go-Kube-Compiler', 'href': None}]}, 'Status': {'id': 'a0c960ca-30de-46df-8bc6-0d8f1c2e1b2b', 'type': 'status', 'status': {'id': 'bae1b841-a999-478a-b25a-f0f88fcebc08', 'name': 'Not started', 'color': 'default'}}}, 'url': 'https://www.notion.so/Go-Kube-Compiler-12f90ef7bebc801690b5d77cc689dbe5', 'public_url': 'https://davidcannan.notion.site/Go-Kube-Compiler-12f90ef7bebc801690b5d77cc689dbe5'}
# {'object': 'page', 'id': '12f90ef7-bebc-80b7-b489-fe6b480eb97f', 'created_time': '2024-10-30T04:19:00.000Z', 'last_edited_time': '2024-10-30T04:20:00.000Z', 'created_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'cover': None, 'icon': {'type': 'emoji', 'emoji': '📗'}, 'parent': {'type': 'database_id', 'database_id': '371d24c0-59fd-4622-a0b7-fa8369bbede8'}, 'archived': False, 'in_trash': False, 'properties': {'Created time': {'id': 'EOiB', 'type': 'created_time', 'created_time': '2024-10-30T04:19:00.000Z'}, 'Last edited by': {'id': 'MNQk', 'type': 'last_edited_by', 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5', 'name': 'David Cannan', 'avatar_url': 'https://lh3.googleusercontent.com/a-/AFdZucpV9CJe58bbkJi0GMZiBz9zgA-FyjhTzsemCkJy488=s100', 'type': 'person', 'person': {'email': 'davidacannan@gmail.com'}}}, 'Last edited time': {'id': 'YwON', 'type': 'last_edited_time', 'last_edited_time': '2024-10-30T04:20:00.000Z'}, 'Tags': {'id': 'prUH', 'type': 'multi_select', 'multi_select': []}, 'ID': {'id': 'r%3DxR', 'type': 'unique_id', 'unique_id': {'prefix': 'BP', 'number': 146}}, 'Title': {'id': 'wZ%7B%7D', 'type': 'rich_text', 'rich_text': []}, 'Name': {'id': 'title', 'type': 'title', 'title': [{'type': 'text', 'text': {'content': 'Practical Data Structures in Golang', 'link': None}, 'annotations': {'bold': False, 'italic': False, 'strikethrough': False, 'underline': False, 'code': False, 'color': 'default'}, 'plain_text': 'Practical Data Structures in Golang', 'href': None}]}, 'Status': {'id': 'a0c960ca-30de-46df-8bc6-0d8f1c2e1b2b', 'type': 'status', 'status': {'id': 'bae1b841-a999-478a-b25a-f0f88fcebc08', 'name': 'Not started', 'color': 'default'}}}, 'url': 'https://www.notion.so/Practical-Data-Structures-in-Golang-12f90ef7bebc80b7b489fe6b480eb97f', 'public_url': 'https://davidcannan.notion.site/Practical-Data-Structures-in-Golang-12f90ef7bebc80b7b489fe6b480eb97f'}
# {'object': 'page', 'id': '12f90ef7-bebc-80b5-a66d-c886f0127b32', 'created_time': '2024-10-30T04:16:00.000Z', 'last_edited_time': '2024-10-30T04:18:00.000Z', 'created_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'cover': None, 'icon': {'type': 'emoji', 'emoji': '📗'}, 'parent': {'type': 'database_id', 'database_id': '371d24c0-59fd-4622-a0b7-fa8369bbede8'}, 'archived': False, 'in_trash': False, 'properties': {'Created time': {'id': 'EOiB', 'type': 'created_time', 'created_time': '2024-10-30T04:16:00.000Z'}, 'Last edited by': {'id': 'MNQk', 'type': 'last_edited_by', 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5', 'name': 'David Cannan', 'avatar_url': 'https://lh3.googleusercontent.com/a-/AFdZucpV9CJe58bbkJi0GMZiBz9zgA-FyjhTzsemCkJy488=s100', 'type': 'person', 'person': {'email': 'davidacannan@gmail.com'}}}, 'Last edited time': {'id': 'YwON', 'type': 'last_edited_time', 'last_edited_time': '2024-10-30T04:18:00.000Z'}, 'Tags': {'id': 'prUH', 'type': 'multi_select', 'multi_select': []}, 'ID': {'id': 'r%3DxR', 'type': 'unique_id', 'unique_id': {'prefix': 'BP', 'number': 145}}, 'Title': {'id': 'wZ%7B%7D', 'type': 'rich_text', 'rich_text': []}, 'Name': {'id': 'title', 'type': 'title', 'title': [{'type': 'text', 'text': {'content': 'Unsafe Memory Operations in Golang', 'link': None}, 'annotations': {'bold': False, 'italic': False, 'strikethrough': False, 'underline': False, 'code': False, 'color': 'default'}, 'plain_text': 'Unsafe Memory Operations in Golang', 'href': None}]}, 'Status': {'id': 'a0c960ca-30de-46df-8bc6-0d8f1c2e1b2b', 'type': 'status', 'status': {'id': 'bae1b841-a999-478a-b25a-f0f88fcebc08', 'name': 'Not started', 'color': 'default'}}}, 'url': 'https://www.notion.so/Unsafe-Memory-Operations-in-Golang-12f90ef7bebc80b5a66dc886f0127b32', 'public_url': 'https://davidcannan.notion.site/Unsafe-Memory-Operations-in-Golang-12f90ef7bebc80b5a66dc886f0127b32'}
# {'object': 'page', 'id': '12f90ef7-bebc-8003-8dc5-db65d4237192', 'created_time': '2024-10-30T04:16:00.000Z', 'last_edited_time': '2024-10-30T04:21:00.000Z', 'created_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'cover': None, 'icon': {'type': 'emoji', 'emoji': '📗'}, 'parent': {'type': 'database_id', 'database_id': '371d24c0-59fd-4622-a0b7-fa8369bbede8'}, 'archived': False, 'in_trash': False, 'properties': {'Created time': {'id': 'EOiB', 'type': 'created_time', 'created_time': '2024-10-30T04:16:00.000Z'}, 'Last edited by': {'id': 'MNQk', 'type': 'last_edited_by', 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5', 'name': 'David Cannan', 'avatar_url': 'https://lh3.googleusercontent.com/a-/AFdZucpV9CJe58bbkJi0GMZiBz9zgA-FyjhTzsemCkJy488=s100', 'type': 'person', 'person': {'email': 'davidacannan@gmail.com'}}}, 'Last edited time': {'id': 'YwON', 'type': 'last_edited_time', 'last_edited_time': '2024-10-30T04:21:00.000Z'}, 'Tags': {'id': 'prUH', 'type': 'multi_select', 'multi_select': []}, 'ID': {'id': 'r%3DxR', 'type': 'unique_id', 'unique_id': {'prefix': 'BP', 'number': 144}}, 'Title': {'id': 'wZ%7B%7D', 'type': 'rich_text', 'rich_text': []}, 'Name': {'id': 'title', 'type': 'title', 'title': [{'type': 'text', 'text': {'content': 'Building VM in Golang', 'link': None}, 'annotations': {'bold': False, 'italic': False, 'strikethrough': False, 'underline': False, 'code': False, 'color': 'default'}, 'plain_text': 'Building VM in Golang', 'href': None}]}, 'Status': {'id': 'a0c960ca-30de-46df-8bc6-0d8f1c2e1b2b', 'type': 'status', 'status': {'id': 'bae1b841-a999-478a-b25a-f0f88fcebc08', 'name': 'Not started', 'color': 'default'}}}, 'url': 'https://www.notion.so/Building-VM-in-Golang-12f90ef7bebc80038dc5db65d4237192', 'public_url': 'https://davidcannan.notion.site/Building-VM-in-Golang-12f90ef7bebc80038dc5db65d4237192'}
# {'object': 'page', 'id': '12f90ef7-bebc-8053-a093-c1e9d5b0084d', 'created_time': '2024-10-30T04:13:00.000Z', 'last_edited_time': '2024-10-30T04:15:00.000Z', 'created_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'cover': None, 'icon': {'type': 'emoji', 'emoji': '📗'}, 'parent': {'type': 'database_id', 'database_id': '371d24c0-59fd-4622-a0b7-fa8369bbede8'}, 'archived': False, 'in_trash': False, 'properties': {'Created time': {'id': 'EOiB', 'type': 'created_time', 'created_time': '2024-10-30T04:13:00.000Z'}, 'Last edited by': {'id': 'MNQk', 'type': 'last_edited_by', 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5', 'name': 'David Cannan', 'avatar_url': 'https://lh3.googleusercontent.com/a-/AFdZucpV9CJe58bbkJi0GMZiBz9zgA-FyjhTzsemCkJy488=s100', 'type': 'person', 'person': {'email': 'davidacannan@gmail.com'}}}, 'Last edited time': {'id': 'YwON', 'type': 'last_edited_time', 'last_edited_time': '2024-10-30T04:15:00.000Z'}, 'Tags': {'id': 'prUH', 'type': 'multi_select', 'multi_select': []}, 'ID': {'id': 'r%3DxR', 'type': 'unique_id', 'unique_id': {'prefix': 'BP', 'number': 143}}, 'Title': {'id': 'wZ%7B%7D', 'type': 'rich_text', 'rich_text': []}, 'Name': {'id': 'title', 'type': 'title', 'title': [{'type': 'text', 'text': {'content': 'How Erasure Coding Works', 'link': None}, 'annotations': {'bold': False, 'italic': False, 'strikethrough': False, 'underline': False, 'code': False, 'color': 'default'}, 'plain_text': 'How Erasure Coding Works', 'href': None}]}, 'Status': {'id': 'a0c960ca-30de-46df-8bc6-0d8f1c2e1b2b', 'type': 'status', 'status': {'id': 'bae1b841-a999-478a-b25a-f0f88fcebc08', 'name': 'Not started', 'color': 'default'}}}, 'url': 'https://www.notion.so/How-Erasure-Coding-Works-12f90ef7bebc8053a093c1e9d5b0084d', 'public_url': 'https://davidcannan.notion.site/How-Erasure-Coding-Works-12f90ef7bebc8053a093c1e9d5b0084d'}
# {'object': 'page', 'id': '12d90ef7-bebc-803a-aa13-eb7330dae3eb', 'created_time': '2024-10-28T17:01:00.000Z', 'last_edited_time': '2024-10-28T17:02:00.000Z', 'created_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'cover': None, 'icon': {'type': 'emoji', 'emoji': '📗'}, 'parent': {'type': 'database_id', 'database_id': '371d24c0-59fd-4622-a0b7-fa8369bbede8'}, 'archived': False, 'in_trash': False, 'properties': {'Created time': {'id': 'EOiB', 'type': 'created_time', 'created_time': '2024-10-28T17:01:00.000Z'}, 'Last edited by': {'id': 'MNQk', 'type': 'last_edited_by', 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5', 'name': 'David Cannan', 'avatar_url': 'https://lh3.googleusercontent.com/a-/AFdZucpV9CJe58bbkJi0GMZiBz9zgA-FyjhTzsemCkJy488=s100', 'type': 'person', 'person': {'email': 'davidacannan@gmail.com'}}}, 'Last edited time': {'id': 'YwON', 'type': 'last_edited_time', 'last_edited_time': '2024-10-28T17:02:00.000Z'}, 'Tags': {'id': 'prUH', 'type': 'multi_select', 'multi_select': []}, 'ID': {'id': 'r%3DxR', 'type': 'unique_id', 'unique_id': {'prefix': 'BP', 'number': 142}}, 'Title': {'id': 'wZ%7B%7D', 'type': 'rich_text', 'rich_text': []}, 'Name': {'id': 'title', 'type': 'title', 'title': [{'type': 'text', 'text': {'content': '“Raising Elephants Is So Utterly Boring” ', 'link': None}, 'annotations': {'bold': False, 'italic': False, 'strikethrough': False, 'underline': False, 'code': False, 'color': 'default'}, 'plain_text': '“Raising Elephants Is So Utterly Boring” ', 'href': None}]}, 'Status': {'id': 'a0c960ca-30de-46df-8bc6-0d8f1c2e1b2b', 'type': 'status', 'status': {'id': 'bae1b841-a999-478a-b25a-f0f88fcebc08', 'name': 'Not started', 'color': 'default'}}}, 'url': 'https://www.notion.so/Raising-Elephants-Is-So-Utterly-Boring-12d90ef7bebc803aaa13eb7330dae3eb', 'public_url': 'https://davidcannan.notion.site/Raising-Elephants-Is-So-Utterly-Boring-12d90ef7bebc803aaa13eb7330dae3eb'}
# {'object': 'page', 'id': '12a90ef7-bebc-8006-a9b9-d3e0e89675b0', 'created_time': '2024-10-25T17:42:00.000Z', 'last_edited_time': '2024-10-25T17:43:00.000Z', 'created_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'cover': None, 'icon': {'type': 'emoji', 'emoji': '📗'}, 'parent': {'type': 'database_id', 'database_id': '371d24c0-59fd-4622-a0b7-fa8369bbede8'}, 'archived': False, 'in_trash': False, 'properties': {'Created time': {'id': 'EOiB', 'type': 'created_time', 'created_time': '2024-10-25T17:42:00.000Z'}, 'Last edited by': {'id': 'MNQk', 'type': 'last_edited_by', 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5', 'name': 'David Cannan', 'avatar_url': 'https://lh3.googleusercontent.com/a-/AFdZucpV9CJe58bbkJi0GMZiBz9zgA-FyjhTzsemCkJy488=s100', 'type': 'person', 'person': {'email': 'davidacannan@gmail.com'}}}, 'Last edited time': {'id': 'YwON', 'type': 'last_edited_time', 'last_edited_time': '2024-10-25T17:43:00.000Z'}, 'Tags': {'id': 'prUH', 'type': 'multi_select', 'multi_select': []}, 'ID': {'id': 'r%3DxR', 'type': 'unique_id', 'unique_id': {'prefix': 'BP', 'number': 141}}, 'Title': {'id': 'wZ%7B%7D', 'type': 'rich_text', 'rich_text': []}, 'Name': {'id': 'title', 'type': 'title', 'title': [{'type': 'text', 'text': {'content': 'TJS - Rails Web Portfolio with Dynamic iFrames', 'link': None}, 'annotations': {'bold': False, 'italic': False, 'strikethrough': False, 'underline': False, 'code': False, 'color': 'default'}, 'plain_text': 'TJS - Rails Web Portfolio with Dynamic iFrames', 'href': None}]}, 'Status': {'id': 'a0c960ca-30de-46df-8bc6-0d8f1c2e1b2b', 'type': 'status', 'status': {'id': 'bae1b841-a999-478a-b25a-f0f88fcebc08', 'name': 'Not started', 'color': 'default'}}}, 'url': 'https://www.notion.so/TJS-Rails-Web-Portfolio-with-Dynamic-iFrames-12a90ef7bebc8006a9b9d3e0e89675b0', 'public_url': 'https://davidcannan.notion.site/TJS-Rails-Web-Portfolio-with-Dynamic-iFrames-12a90ef7bebc8006a9b9d3e0e89675b0'}
# {'object': 'page', 'id': '12990ef7-bebc-8023-9642-eba6eaecd481', 'created_time': '2024-10-24T20:47:00.000Z', 'last_edited_time': '2024-10-24T20:48:00.000Z', 'created_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'cover': None, 'icon': {'type': 'emoji', 'emoji': '📗'}, 'parent': {'type': 'database_id', 'database_id': '371d24c0-59fd-4622-a0b7-fa8369bbede8'}, 'archived': False, 'in_trash': False, 'properties': {'Created time': {'id': 'EOiB', 'type': 'created_time', 'created_time': '2024-10-24T20:47:00.000Z'}, 'Last edited by': {'id': 'MNQk', 'type': 'last_edited_by', 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5', 'name': 'David Cannan', 'avatar_url': 'https://lh3.googleusercontent.com/a-/AFdZucpV9CJe58bbkJi0GMZiBz9zgA-FyjhTzsemCkJy488=s100', 'type': 'person', 'person': {'email': 'davidacannan@gmail.com'}}}, 'Last edited time': {'id': 'YwON', 'type': 'last_edited_time', 'last_edited_time': '2024-10-24T20:48:00.000Z'}, 'Tags': {'id': 'prUH', 'type': 'multi_select', 'multi_select': []}, 'ID': {'id': 'r%3DxR', 'type': 'unique_id', 'unique_id': {'prefix': 'BP', 'number': 140}}, 'Title': {'id': 'wZ%7B%7D', 'type': 'rich_text', 'rich_text': []}, 'Name': {'id': 'title', 'type': 'title', 'title': [{'type': 'text', 'text': {'content': 'Multi-axis motorized camera motion with record and playback motions', 'link': None}, 'annotations': {'bold': False, 'italic': False, 'strikethrough': False, 'underline': False, 'code': False, 'color': 'default'}, 'plain_text': 'Multi-axis motorized camera motion with record and playback motions', 'href': None}]}, 'Status': {'id': 'a0c960ca-30de-46df-8bc6-0d8f1c2e1b2b', 'type': 'status', 'status': {'id': 'bae1b841-a999-478a-b25a-f0f88fcebc08', 'name': 'Not started', 'color': 'default'}}}, 'url': 'https://www.notion.so/Multi-axis-motorized-camera-motion-with-record-and-playback-motions-12990ef7bebc80239642eba6eaecd481', 'public_url': 'https://davidcannan.notion.site/Multi-axis-motorized-camera-motion-with-record-and-playback-motions-12990ef7bebc80239642eba6eaecd481'}
# {'object': 'page', 'id': '12990ef7-bebc-804d-9a94-fcd9731d6ecd', 'created_time': '2024-10-24T14:01:00.000Z', 'last_edited_time': '2024-10-24T14:02:00.000Z', 'created_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'cover': None, 'icon': {'type': 'emoji', 'emoji': '📗'}, 'parent': {'type': 'database_id', 'database_id': '371d24c0-59fd-4622-a0b7-fa8369bbede8'}, 'archived': False, 'in_trash': False, 'properties': {'Created time': {'id': 'EOiB', 'type': 'created_time', 'created_time': '2024-10-24T14:01:00.000Z'}, 'Last edited by': {'id': 'MNQk', 'type': 'last_edited_by', 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5', 'name': 'David Cannan', 'avatar_url': 'https://lh3.googleusercontent.com/a-/AFdZucpV9CJe58bbkJi0GMZiBz9zgA-FyjhTzsemCkJy488=s100', 'type': 'person', 'person': {'email': 'davidacannan@gmail.com'}}}, 'Last edited time': {'id': 'YwON', 'type': 'last_edited_time', 'last_edited_time': '2024-10-24T14:02:00.000Z'}, 'Tags': {'id': 'prUH', 'type': 'multi_select', 'multi_select': []}, 'ID': {'id': 'r%3DxR', 'type': 'unique_id', 'unique_id': {'prefix': 'BP', 'number': 139}}, 'Title': {'id': 'wZ%7B%7D', 'type': 'rich_text', 'rich_text': []}, 'Name': {'id': 'title', 'type': 'title', 'title': [{'type': 'text', 'text': {'content': 'App-Frontend and Middlware Registry  ', 'link': None}, 'annotations': {'bold': False, 'italic': False, 'strikethrough': False, 'underline': False, 'code': False, 'color': 'default'}, 'plain_text': 'App-Frontend and Middlware Registry  ', 'href': None}]}, 'Status': {'id': 'a0c960ca-30de-46df-8bc6-0d8f1c2e1b2b', 'type': 'status', 'status': {'id': 'bae1b841-a999-478a-b25a-f0f88fcebc08', 'name': 'Not started', 'color': 'default'}}}, 'url': 'https://www.notion.so/App-Frontend-and-Middlware-Registry-12990ef7bebc804d9a94fcd9731d6ecd', 'public_url': 'https://davidcannan.notion.site/App-Frontend-and-Middlware-Registry-12990ef7bebc804d9a94fcd9731d6ecd'}
# {'object': 'page', 'id': '12590ef7-bebc-800e-9717-cd42bff2ff7c', 'created_time': '2024-10-20T20:54:00.000Z', 'last_edited_time': '2024-10-20T21:09:00.000Z', 'created_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'cover': None, 'icon': {'type': 'emoji', 'emoji': '📗'}, 'parent': {'type': 'database_id', 'database_id': '371d24c0-59fd-4622-a0b7-fa8369bbede8'}, 'archived': False, 'in_trash': False, 'properties': {'Created time': {'id': 'EOiB', 'type': 'created_time', 'created_time': '2024-10-20T20:54:00.000Z'}, 'Last edited by': {'id': 'MNQk', 'type': 'last_edited_by', 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5', 'name': 'David Cannan', 'avatar_url': 'https://lh3.googleusercontent.com/a-/AFdZucpV9CJe58bbkJi0GMZiBz9zgA-FyjhTzsemCkJy488=s100', 'type': 'person', 'person': {'email': 'davidacannan@gmail.com'}}}, 'Last edited time': {'id': 'YwON', 'type': 'last_edited_time', 'last_edited_time': '2024-10-20T21:09:00.000Z'}, 'Tags': {'id': 'prUH', 'type': 'multi_select', 'multi_select': [{'id': '38f78354-ded5-465f-94fd-48f49b8a088c', 'name': 'Cognative Self Development', 'color': 'pink'}, {'id': '2604bd80-4b3a-4172-a6af-db6fbe12a3e2', 'name': 'Hero’s Journey', 'color': 'red'}]}, 'ID': {'id': 'r%3DxR', 'type': 'unique_id', 'unique_id': {'prefix': 'BP', 'number': 137}}, 'Title': {'id': 'wZ%7B%7D', 'type': 'rich_text', 'rich_text': []}, 'Name': {'id': 'title', 'type': 'title', 'title': [{'type': 'text', 'text': {'content': 'Never Lose Your Potential: ', 'link': None}, 'annotations': {'bold': False, 'italic': False, 'strikethrough': False, 'underline': False, 'code': False, 'color': 'default'}, 'plain_text': 'Never Lose Your Potential: ', 'href': None}, {'type': 'text', 'text': {'content': 'A Journey Through Shadow and Heroism', 'link': None}, 'annotations': {'bold': True, 'italic': False, 'strikethrough': False, 'underline': False, 'code': False, 'color': 'default'}, 'plain_text': 'A Journey Through Shadow and Heroism', 'href': None}]}, 'Status': {'id': 'a0c960ca-30de-46df-8bc6-0d8f1c2e1b2b', 'type': 'status', 'status': {'id': 'e6e14087-75c0-44f2-899a-12dc16eac2d6', 'name': 'Done', 'color': 'green'}}}, 'url': 'https://www.notion.so/Never-Lose-Your-Potential-A-Journey-Through-Shadow-and-Heroism-12590ef7bebc800e9717cd42bff2ff7c', 'public_url': 'https://davidcannan.notion.site/Never-Lose-Your-Potential-A-Journey-Through-Shadow-and-Heroism-12590ef7bebc800e9717cd42bff2ff7c'}
# ...
# {'object': 'page', 'id': 'e53a64f5-2892-404b-8ea0-10b4fc651c2b', 'created_time': '2023-12-09T15:53:00.000Z', 'last_edited_time': '2024-01-02T16:12:00.000Z', 'created_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'cover': None, 'icon': {'type': 'emoji', 'emoji': '📒'}, 'parent': {'type': 'database_id', 'database_id': '371d24c0-59fd-4622-a0b7-fa8369bbede8'}, 'archived': False, 'in_trash': False, 'properties': {'Created time': {'id': 'EOiB', 'type': 'created_time', 'created_time': '2023-12-09T15:53:00.000Z'}, 'Last edited by': {'id': 'MNQk', 'type': 'last_edited_by', 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5', 'name': 'David Cannan', 'avatar_url': 'https://lh3.googleusercontent.com/a-/AFdZucpV9CJe58bbkJi0GMZiBz9zgA-FyjhTzsemCkJy488=s100', 'type': 'person', 'person': {'email': 'davidacannan@gmail.com'}}}, 'Last edited time': {'id': 'YwON', 'type': 'last_edited_time', 'last_edited_time': '2024-01-02T16:12:00.000Z'}, 'Tags': {'id': 'prUH', 'type': 'multi_select', 'multi_select': []}, 'ID': {'id': 'r%3DxR', 'type': 'unique_id', 'unique_id': {'prefix': 'BP', 'number': 65}}, 'Title': {'id': 'wZ%7B%7D', 'type': 'rich_text', 'rich_text': []}, 'Name': {'id': 'title', 'type': 'title', 'title': [{'type': 'text', 'text': {'content': 'MinIO Event Notifications: A Developer’s Guide for a Streamlined Data Workflow', 'link': None}, 'annotations': {'bold': False, 'italic': False, 'strikethrough': False, 'underline': False, 'code': False, 'color': 'default'}, 'plain_text': 'MinIO Event Notifications: A Developer’s Guide for a Streamlined Data Workflow', 'href': None}]}, 'Status': {'id': 'a0c960ca-30de-46df-8bc6-0d8f1c2e1b2b', 'type': 'status', 'status': {'id': 'e03198d4-8dfe-418d-bc3a-2d26d6ad70c0', 'name': 'In progress', 'color': 'blue'}}}, 'url': 'https://www.notion.so/MinIO-Event-Notifications-A-Developer-s-Guide-for-a-Streamlined-Data-Workflow-e53a64f52892404b8ea010b4fc651c2b', 'public_url': 'https://davidcannan.notion.site/MinIO-Event-Notifications-A-Developer-s-Guide-for-a-Streamlined-Data-Workflow-e53a64f52892404b8ea010b4fc651c2b'}
# {'object': 'page', 'id': '0c5e70ee-736f-49eb-90dc-634a6290b257', 'created_time': '2023-12-05T16:19:00.000Z', 'last_edited_time': '2023-12-05T16:19:00.000Z', 'created_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'cover': None, 'icon': {'type': 'emoji', 'emoji': '📒'}, 'parent': {'type': 'database_id', 'database_id': '371d24c0-59fd-4622-a0b7-fa8369bbede8'}, 'archived': False, 'in_trash': False, 'properties': {'Created time': {'id': 'EOiB', 'type': 'created_time', 'created_time': '2023-12-05T16:19:00.000Z'}, 'Last edited by': {'id': 'MNQk', 'type': 'last_edited_by', 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5', 'name': 'David Cannan', 'avatar_url': 'https://lh3.googleusercontent.com/a-/AFdZucpV9CJe58bbkJi0GMZiBz9zgA-FyjhTzsemCkJy488=s100', 'type': 'person', 'person': {'email': 'davidacannan@gmail.com'}}}, 'Last edited time': {'id': 'YwON', 'type': 'last_edited_time', 'last_edited_time': '2023-12-05T16:19:00.000Z'}, 'Tags': {'id': 'prUH', 'type': 'multi_select', 'multi_select': []}, 'ID': {'id': 'r%3DxR', 'type': 'unique_id', 'unique_id': {'prefix': 'BP', 'number': 62}}, 'Title': {'id': 'wZ%7B%7D', 'type': 'rich_text', 'rich_text': []}, 'Name': {'id': 'title', 'type': 'title', 'title': [{'type': 'text', 'text': {'content': 'Creating indexes and nodes out of buckets of text data', 'link': None}, 'annotations': {'bold': False, 'italic': False, 'strikethrough': False, 'underline': False, 'code': False, 'color': 'default'}, 'plain_text': 'Creating indexes and nodes out of buckets of text data', 'href': None}]}, 'Status': {'id': 'a0c960ca-30de-46df-8bc6-0d8f1c2e1b2b', 'type': 'status', 'status': {'id': 'e6e14087-75c0-44f2-899a-12dc16eac2d6', 'name': 'Done', 'color': 'green'}}}, 'url': 'https://www.notion.so/Creating-indexes-and-nodes-out-of-buckets-of-text-data-0c5e70ee736f49eb90dc634a6290b257', 'public_url': 'https://davidcannan.notion.site/Creating-indexes-and-nodes-out-of-buckets-of-text-data-0c5e70ee736f49eb90dc634a6290b257'}
# {'object': 'page', 'id': '3e265ce0-4417-4439-a1e5-4235d3e262bc', 'created_time': '2023-12-03T23:41:00.000Z', 'last_edited_time': '2023-12-24T23:05:00.000Z', 'created_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'cover': None, 'icon': {'type': 'emoji', 'emoji': '📒'}, 'parent': {'type': 'database_id', 'database_id': '371d24c0-59fd-4622-a0b7-fa8369bbede8'}, 'archived': False, 'in_trash': False, 'properties': {'Created time': {'id': 'EOiB', 'type': 'created_time', 'created_time': '2023-12-03T23:41:00.000Z'}, 'Last edited by': {'id': 'MNQk', 'type': 'last_edited_by', 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5', 'name': 'David Cannan', 'avatar_url': 'https://lh3.googleusercontent.com/a-/AFdZucpV9CJe58bbkJi0GMZiBz9zgA-FyjhTzsemCkJy488=s100', 'type': 'person', 'person': {'email': 'davidacannan@gmail.com'}}}, 'Last edited time': {'id': 'YwON', 'type': 'last_edited_time', 'last_edited_time': '2023-12-24T23:05:00.000Z'}, 'Tags': {'id': 'prUH', 'type': 'multi_select', 'multi_select': []}, 'ID': {'id': 'r%3DxR', 'type': 'unique_id', 'unique_id': {'prefix': 'BP', 'number': 61}}, 'Title': {'id': 'wZ%7B%7D', 'type': 'rich_text', 'rich_text': [{'type': 'text', 'text': {'content': 'MinIO+Weaviate: A Journey Towards Efficient Data Management', 'link': None}, 'annotations': {'bold': True, 'italic': False, 'strikethrough': False, 'underline': False, 'code': False, 'color': 'default'}, 'plain_text': 'MinIO+Weaviate: A Journey Towards Efficient Data Management', 'href': None}]}, 'Name': {'id': 'title', 'type': 'title', 'title': [{'type': 'text', 'text': {'content': 'MinIO + Weaviate + AirByte', 'link': None}, 'annotations': {'bold': False, 'italic': False, 'strikethrough': False, 'underline': False, 'code': False, 'color': 'default'}, 'plain_text': 'MinIO + Weaviate + AirByte', 'href': None}]}, 'Status': {'id': 'a0c960ca-30de-46df-8bc6-0d8f1c2e1b2b', 'type': 'status', 'status': {'id': 'e6e14087-75c0-44f2-899a-12dc16eac2d6', 'name': 'Done', 'color': 'green'}}}, 'url': 'https://www.notion.so/MinIO-Weaviate-AirByte-3e265ce044174439a1e54235d3e262bc', 'public_url': 'https://davidcannan.notion.site/MinIO-Weaviate-AirByte-3e265ce044174439a1e54235d3e262bc'}
# {'object': 'page', 'id': '25a501ab-412f-489e-be01-f1e740876b7e', 'created_time': '2023-12-03T23:30:00.000Z', 'last_edited_time': '2023-12-03T23:33:00.000Z', 'created_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'cover': None, 'icon': {'type': 'emoji', 'emoji': '📒'}, 'parent': {'type': 'database_id', 'database_id': '371d24c0-59fd-4622-a0b7-fa8369bbede8'}, 'archived': False, 'in_trash': False, 'properties': {'Created time': {'id': 'EOiB', 'type': 'created_time', 'created_time': '2023-12-03T23:30:00.000Z'}, 'Last edited by': {'id': 'MNQk', 'type': 'last_edited_by', 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5', 'name': 'David Cannan', 'avatar_url': 'https://lh3.googleusercontent.com/a-/AFdZucpV9CJe58bbkJi0GMZiBz9zgA-FyjhTzsemCkJy488=s100', 'type': 'person', 'person': {'email': 'davidacannan@gmail.com'}}}, 'Last edited time': {'id': 'YwON', 'type': 'last_edited_time', 'last_edited_time': '2023-12-03T23:33:00.000Z'}, 'Tags': {'id': 'prUH', 'type': 'multi_select', 'multi_select': []}, 'ID': {'id': 'r%3DxR', 'type': 'unique_id', 'unique_id': {'prefix': 'BP', 'number': 60}}, 'Title': {'id': 'wZ%7B%7D', 'type': 'rich_text', 'rich_text': []}, 'Name': {'id': 'title', 'type': 'title', 'title': [{'type': 'text', 'text': {'content': 'MinIO + Kong  - API Gateway', 'link': None}, 'annotations': {'bold': False, 'italic': False, 'strikethrough': False, 'underline': False, 'code': False, 'color': 'default'}, 'plain_text': 'MinIO + Kong  - API Gateway', 'href': None}]}, 'Status': {'id': 'a0c960ca-30de-46df-8bc6-0d8f1c2e1b2b', 'type': 'status', 'status': {'id': 'e6e14087-75c0-44f2-899a-12dc16eac2d6', 'name': 'Done', 'color': 'green'}}}, 'url': 'https://www.notion.so/MinIO-Kong-API-Gateway-25a501ab412f489ebe01f1e740876b7e', 'public_url': 'https://davidcannan.notion.site/MinIO-Kong-API-Gateway-25a501ab412f489ebe01f1e740876b7e'}
# {'object': 'page', 'id': '71d771c1-93a3-42f7-a3f2-6e9d86ebc44c', 'created_time': '2023-12-03T20:32:00.000Z', 'last_edited_time': '2023-12-03T20:32:00.000Z', 'created_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'cover': None, 'icon': {'type': 'emoji', 'emoji': '📒'}, 'parent': {'type': 'database_id', 'database_id': '371d24c0-59fd-4622-a0b7-fa8369bbede8'}, 'archived': False, 'in_trash': False, 'properties': {'Created time': {'id': 'EOiB', 'type': 'created_time', 'created_time': '2023-12-03T20:32:00.000Z'}, 'Last edited by': {'id': 'MNQk', 'type': 'last_edited_by', 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5', 'name': 'David Cannan', 'avatar_url': 'https://lh3.googleusercontent.com/a-/AFdZucpV9CJe58bbkJi0GMZiBz9zgA-FyjhTzsemCkJy488=s100', 'type': 'person', 'person': {'email': 'davidacannan@gmail.com'}}}, 'Last edited time': {'id': 'YwON', 'type': 'last_edited_time', 'last_edited_time': '2023-12-03T20:32:00.000Z'}, 'Tags': {'id': 'prUH', 'type': 'multi_select', 'multi_select': []}, 'ID': {'id': 'r%3DxR', 'type': 'unique_id', 'unique_id': {'prefix': 'BP', 'number': 59}}, 'Title': {'id': 'wZ%7B%7D', 'type': 'rich_text', 'rich_text': []}, 'Name': {'id': 'title', 'type': 'title', 'title': [{'type': 'text', 'text': {'content': 'Building a Home Lab with MinIO at its core', 'link': None}, 'annotations': {'bold': False, 'italic': False, 'strikethrough': False, 'underline': False, 'code': False, 'color': 'default'}, 'plain_text': 'Building a Home Lab with MinIO at its core', 'href': None}]}, 'Status': {'id': 'a0c960ca-30de-46df-8bc6-0d8f1c2e1b2b', 'type': 'status', 'status': {'id': 'e6e14087-75c0-44f2-899a-12dc16eac2d6', 'name': 'Done', 'color': 'green'}}}, 'url': 'https://www.notion.so/Building-a-Home-Lab-with-MinIO-at-its-core-71d771c193a342f7a3f26e9d86ebc44c', 'public_url': 'https://davidcannan.notion.site/Building-a-Home-Lab-with-MinIO-at-its-core-71d771c193a342f7a3f26e9d86ebc44c'}
# {'object': 'page', 'id': '75145237-24cf-49cc-a1d7-75e728e5c675', 'created_time': '2023-11-28T15:40:00.000Z', 'last_edited_time': '2023-11-28T16:39:00.000Z', 'created_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'cover': None, 'icon': {'type': 'emoji', 'emoji': '📒'}, 'parent': {'type': 'database_id', 'database_id': '371d24c0-59fd-4622-a0b7-fa8369bbede8'}, 'archived': False, 'in_trash': False, 'properties': {'Created time': {'id': 'EOiB', 'type': 'created_time', 'created_time': '2023-11-28T15:40:00.000Z'}, 'Last edited by': {'id': 'MNQk', 'type': 'last_edited_by', 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5', 'name': 'David Cannan', 'avatar_url': 'https://lh3.googleusercontent.com/a-/AFdZucpV9CJe58bbkJi0GMZiBz9zgA-FyjhTzsemCkJy488=s100', 'type': 'person', 'person': {'email': 'davidacannan@gmail.com'}}}, 'Last edited time': {'id': 'YwON', 'type': 'last_edited_time', 'last_edited_time': '2023-11-28T16:39:00.000Z'}, 'Tags': {'id': 'prUH', 'type': 'multi_select', 'multi_select': []}, 'ID': {'id': 'r%3DxR', 'type': 'unique_id', 'unique_id': {'prefix': 'BP', 'number': 58}}, 'Title': {'id': 'wZ%7B%7D', 'type': 'rich_text', 'rich_text': [{'type': 'text', 'text': {'content': 'Revolutionizing AI Data Management: The Synergy of MinIO and Weaviate', 'link': None}, 'annotations': {'bold': False, 'italic': False, 'strikethrough': False, 'underline': False, 'code': False, 'color': 'default'}, 'plain_text': 'Revolutionizing AI Data Management: The Synergy of MinIO and Weaviate', 'href': None}]}, 'Name': {'id': 'title', 'type': 'title', 'title': [{'type': 'text', 'text': {'content': 'Data Innovation with MinIO and Weaviate', 'link': None}, 'annotations': {'bold': False, 'italic': False, 'strikethrough': False, 'underline': False, 'code': False, 'color': 'default'}, 'plain_text': 'Data Innovation with MinIO and Weaviate', 'href': None}]}, 'Status': {'id': 'a0c960ca-30de-46df-8bc6-0d8f1c2e1b2b', 'type': 'status', 'status': {'id': 'e6e14087-75c0-44f2-899a-12dc16eac2d6', 'name': 'Done', 'color': 'green'}}}, 'url': 'https://www.notion.so/Data-Innovation-with-MinIO-and-Weaviate-7514523724cf49cca1d775e728e5c675', 'public_url': 'https://davidcannan.notion.site/Data-Innovation-with-MinIO-and-Weaviate-7514523724cf49cca1d775e728e5c675'}
# {'object': 'page', 'id': '02e3bc3e-afce-40de-b4be-eb6e34d2a649', 'created_time': '2023-11-27T08:31:00.000Z', 'last_edited_time': '2023-11-27T08:37:00.000Z', 'created_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5'}, 'cover': None, 'icon': {'type': 'emoji', 'emoji': '📒'}, 'parent': {'type': 'database_id', 'database_id': '371d24c0-59fd-4622-a0b7-fa8369bbede8'}, 'archived': False, 'in_trash': False, 'properties': {'Created time': {'id': 'EOiB', 'type': 'created_time', 'created_time': '2023-11-27T08:31:00.000Z'}, 'Last edited by': {'id': 'MNQk', 'type': 'last_edited_by', 'last_edited_by': {'object': 'user', 'id': '5c0ade10-6fb0-459c-bd30-0571b86d02e5', 'name': 'David Cannan', 'avatar_url': 'https://lh3.googleusercontent.com/a-/AFdZucpV9CJe58bbkJi0GMZiBz9zgA-FyjhTzsemCkJy488=s100', 'type': 'person', 'person': {'email': 'davidacannan@gmail.com'}}}, 'Last edited time': {'id': 'YwON', 'type': 'last_edited_time', 'last_edited_time': '2023-11-27T08:37:00.000Z'}, 'Tags': {'id': 'prUH', 'type': 'multi_select', 'multi_select': []}, 'ID': {'id': 'r%3DxR', 'type': 'unique_id', 'unique_id': {'prefix': 'BP', 'number': 57}}, 'Title': {'id': 'wZ%7B%7D', 'type': 'rich_text', 'rich_text': []}, 'Name': {'id': 'title', 'type': 'title', 'title': [{'type': 'text', 'text': {'content': 'MinIO API Table', 'link': None}, 'annotations': {'bold': False, 'italic': False, 'strikethrough': False, 'underline': False, 'code': False, 'color': 'default'}, 'plain_text': 'MinIO API Table', 'href': None}]}, 'Status': {'id': 'a0c960ca-30de-46df-8bc6-0d8f1c2e1b2b', 'type': 'status', 'status': {'id': 'e6e14087-75c0-44f2-899a-12dc16eac2d6', 'name': 'Done', 'color': 'green'}}}, 'url': 'https://www.notion.so/MinIO-API-Table-02e3bc3eafce40deb4beeb6e34d2a649', 'public_url': 'https://davidcannan.notion.site/MinIO-API-Table-02e3bc3eafce40deb4beeb6e34d2a649'}

# %% [markdown]
# ## Fetch All Pages found in Database

# %%
# Function to handle pagination for large databases
def fetch_all_notion_pages(database_id):
    results = []
    next_cursor = None

    while True:
        response = notion.databases.query(database_id=database_id, start_cursor=next_cursor)
        results.extend(response['results'])
        next_cursor = response.get('next_cursor')
        
        if not next_cursor:
            break

    return results

# Fetch all pages and display the number of pages found
all_notion_pages = fetch_all_notion_pages(NOTION_DATABASE_ID)
print(f"Total number of pages found: {len(all_notion_pages)}")
# Out:
# Total number of pages found: 148

# %% [markdown]
# ## List All Pages by Title

# %%
# Function to display the titles of all pages
def display_page_titles(pages):
    for page in pages:
        title_property = page['properties']['Name']['title']
        if title_property:
            title = title_property[0]['plain_text']
            print(f"Page Title: {title}")
        else:
            print("Unnamed page")

# Display the titles of all pages
display_page_titles(all_notion_pages)
# Out:
# Page Title: Raspberry Pi Cluster
# Page Title: Mastering Emotional Detachment: Nurturing Relationships Without Losing Yourself
# Page Title: Sanity Blog Registry Clap Back 👏
# Page Title: Guide to Focus
# Page Title: Hash Tables and Hashing in Data Structures and Algorithms (DSA)
# Page Title: Why Mastering Emotional Detachment is a Good Thing for Connection
# Page Title: What’s an Edge Case in Problem Solving
# Page Title: David’s 10 Year Guide to Starting Fresh and being Successful
# Page Title: Learn Go Through Real Questions
# Page Title: RTMP Golang Project
# Page Title: From Service to Micro Service
# Page Title: BlogPost
# Page Title: Designing a Principled Registry
# Page Title: Go-Kube-Compiler
# Page Title: Practical Data Structures in Golang
# Page Title: Unsafe Memory Operations in Golang
# Page Title: Building VM in Golang
# Page Title: How Erasure Coding Works
# Page Title: “Raising Elephants Is So Utterly Boring”
# Page Title: TJS - Rails Web Portfolio with Dynamic iFrames
# Page Title: Multi-axis motorized camera motion with record and playback motions
# Page Title: App-Frontend and Middlware Registry
# Page Title: Never Lose Your Potential:
# Page Title: Go-based middleware application that integrates Notion with Sanity Headless Blog
# Page Title: TypeScript-based solution tailored for a Next.js Sanity & Notion Integration
# Page Title: Multi Series Registry Service Design Patterns & Planning
# Page Title: Planning a Golang Registry Service Design
# Page Title: Registry Service Architecture
# Page Title: From Humble Beginnings
# Page Title: Fun Dev Stuff
# Page Title: Make My Own Borg
# Page Title: Working Copy iOS: WebDev + X-Callback-URL
# Page Title: Cdaprod’s TMUX Configurations
# Page Title: Cdaprod’s WorkingCopy iOS
# Page Title: Building a Plugin System
# Page Title: Request Interception
# Page Title: GoProxy vs Content Blockers
# Page Title: Golang: Shared State vs Shared Object
# Page Title: Go-AI-Agentic-System
# Page Title: Portable Asciinema Server
# Page Title: Learning Golang Syntax
# Page Title: Binary Search Algorithm
# Page Title: CDA Protocol & Kubernetes Roadmap
# Page Title: Jekyl Site for Cdaprod/Cdaprod/docs/
# Page Title: From Existing Projects to Production
# Page Title: Why Interoperability is Critical
# Page Title: Advanced HTML Chat App
# Page Title: Simple HTML Chat Interface
# Page Title: Living Off The Land: Request Handling Edition
# Page Title: Living Off The Land
# Page Title: BlogPost
# Page Title: Cdaprod’s Tmux Command Cheatsheet
# Page Title: Cdaprod’s Vim Motions Cheatsheet
# Page Title: Neovim & Tmux Project Shell
# Page Title: Vim Motions
# Page Title: Ycombinator Startup Application for CDAProd (Core Data Architecture Production)
# Page Title: Unveiling the Magic SysRq Key: The Hidden Power of Your Keyboard
# Page Title: Provisioning Storage for Docker & Kubernetes
# Page Title: My Journey to Goguma
# Page Title: MIGRATING - Addition of NVME
# Page Title: 24 Rules for AI System Design
# Page Title: [Proto First] Code Development Strategy
# Page Title: Extracting Code - AI Agents and Tools
# Page Title: [Shortcuts iOS] Alternate Screenshot Message Response with OpenAI
# Page Title: [openai] Websocket App
# Page Title: Oneliner [Load Environ Variables]
# Page Title: Workaround [Module Not Found]
# Page Title: Workaround [orjson]
# Page Title: Setup Zioxide
# Page Title: Seamless: MinIO and Prometheus
# Page Title: Expanding Docker Storage with NVMe on CasaOS: A Comprehensive Guide
# Page Title: Modeling Data with msgspec
# Page Title: Ensuring High Availability in Distributed Systems: A Comprehensive DevOps Guide
# Page Title: Portable WiFi 6 Repeater: Secure Internet Anywhere with Tailscale Integration
# Page Title: Creating a Scalable Blog Solution in Golang
# Page Title: Essential Python Functions for Parsing Data in DevOps and AIOps
# Page Title: Learn These Functions (DevOps)
# Page Title: Hybrid-Cloud AIOps Development: GitOps CI/CD Pipeline with MinIO Weaviate and Tailscale
# Page Title: BlogPost
# Page Title: [BLOG] GitHub Self-Hosted Runner on Docker Swarm Leader
# Page Title: [POC] Event-Driven Architecture: MinIO Integrations - Automating Bucket Events with Python Webhooks
# Page Title: Streamlining Data Events with MinIO and PostgreSQL
# Page Title: MinIO - Weaviate | LangChain Loader
# Page Title: Langchain + Autogen + LM-Studio
# Page Title: Pi Clustering
# Page Title: Pydantic & MinIO for Custom Object Storage
# Page Title: Journey Through Developing a LangChain and MinIO Integrated Application
# Page Title: Addressing Misconceptions: The Unified Nature of MinIO Event Notifications and Webhooks
# Page Title: The Webhook Paradigm in MinIO's Event Notification System
# Page Title: Building an Integrated Data Handling System with Flask, MinIO, PostgreSQL, and Redis
# Page Title: Article 1: "Harnessing the Power of MinIO Event Notifications: A Comprehensive Guide for Developers"
# Page Title: Programatically Deploy MinIO with Docker SDK
# Page Title: Revolutionizing Data Management with a Custom Hybrid Datastore - Integrating MinIO as a ChatGPT Datastore
# Page Title: MinIO Event Notifications: A Developer’s Guide for a Streamlined Data Workflow
# Page Title: Creating indexes and nodes out of buckets of text data
# Page Title: MinIO + Weaviate + AirByte
# Page Title: MinIO + Kong  - API Gateway
# Page Title: Building a Home Lab with MinIO at its core
# Page Title: Data Innovation with MinIO and Weaviate
# Page Title: MinIO API Table
# Page Title: Canopy MinIO Weaviate RAG Indexes
# Page Title: MinIO serves as the primary data repository
# Page Title: Empowering Data Management: Integrating MinIO with LangChain for Advanced Python Applications
# Page Title: Revolutionizing Data Management with MinIO: A Python Developer's Journey
# Page Title: Automating Metadata Management in MinIO with Flask
# Page Title: Smooth Sailing from Docker to Localhost: A Developer's Guide
# Page Title: I love Go!
# Page Title: Advice from tech giants
# Page Title: Docker Tailscale MinIO
# Page Title: ComeUp
# Page Title: Introduction to Langchain and LCEL for Data Structuring in MinIO
# Page Title: Ingesting Structured Objects into Weaviate
# Page Title: Scraping Sanity Blog
# Page Title: From Traditional Craftsmanship to  Modern Technology: A Journey of Passion
# Page Title: MinIO Merch
# Page Title: Retrieval Augmented Generation
# Page Title: The Evolution of Object Storage: From Academic Concept to Cloud Revolution
# Page Title: Schema Migration Guide for Sanity
# Page Title: Writing Weaviate Schemas, Type Schema, and Exploring Vector Stores
# Page Title: Weaviate Experiences
# Page Title: My Journey with Automating Stock Video Metadata with MinIO and Python
# Page Title: Integrating Home Systems into a Unified Application: A Developer's Journey
# Page Title: Article Title:
# Page Title: Ansible Roles and OpenAI
# Page Title: BugBountySystem
# Page Title: Pwnagotchi for Sanity.Cdaprod.dev
# Page Title: Troubleshooting WSL2
# Page Title: Harnessing Reconnaissance Data
# Page Title: Blog Post #Create 3D Parallax Site
# Page Title: Blog Post #Business Starting Roadmap
# Page Title: Blog Post #GoogleSheets⇒Github
# Page Title: Blog Post #somethn somethn local storage…
# Page Title: Blog Post #PromptEngineering
# Page Title: Blog Post #Bill Gates’ Clone
# Page Title: Blog Post #DIY RESPONDER PY
# Page Title: Blog Post #Threejs Quiz
# Page Title: Ghidra - Reverse Engineering Toolkit
# Page Title: Blog Post #change domain name on Linux server
# Page Title: Blog Post #How to deploy Node apps
# Page Title: Blog Post #ansible
# Page Title: Blog Post Sanity
# Page Title: Blog Post - Linux CLI & Storage
# Page Title: Social Posts with Jupyter Notebooks
# Page Title: Online Accounts
# Page Title: Marketing Custom Logo's
# Page Title: Blog Post #3
# Page Title: Blog Post #2
# Page Title: Blog Post #1

# %% [markdown]
# ## Part 2: Filtering Fetched Pages

# %%
# Function to fetch pages filtered by a specific metadata property (e.g., tag)
def fetch_filtered_notion_pages(database_id, filter_property, filter_value):
    response = notion.databases.query(
        database_id=database_id,
        filter={
            "property": filter_property,
            "multi_select": {
                "contains": filter_value
            }
        }
    )
    return response['results']

# Example usage: Replace 'Tags' with the property name and 'Important' with the filter value
filter_property = 'Tags'  # Replace with the name of your property
filter_value = 'Sanity Dataset'  # Replace with the value you want to filter by

filtered_pages = fetch_filtered_notion_pages(NOTION_DATABASE_ID, filter_property, filter_value)
print(f"Number of filtered pages found: {len(filtered_pages)}")
# Out:
# Number of filtered pages found: 1

# %% [markdown]
# # Function to fetch content from a Notion page and convert to Portable Text
# ## Function to parse Notion rich text (same as before)

# %%
def fetch_page_content(page_id):
    response = notion.blocks.children.list(page_id)
    return response['results']

# Function to convert Notion page content to Portable Text schema
def parse_page_content_to_portable_text(page_content):
    portable_text = []
    for block in page_content:
        block_type = block.get('type')
        if block_type in ['paragraph', 'heading_1', 'heading_2', 'heading_3']:
            style = 'normal' if block_type == 'paragraph' else block_type.replace('_', '')
            text_content = block[block_type].get('rich_text', [])
            children = parse_notion_rich_text(text_content)
            portable_text.append({
                "_type": "block",
                "style": style,
                "children": children
            })
        # Add cases for other block types as needed
    return portable_text

# Function to parse Notion rich text (same as before)
def parse_notion_rich_text(rich_text_array):
    children = []
    for text in rich_text_array:
        marks = []
        annotations = text.get('annotations', {})
        if annotations.get('bold'):
            marks.append('strong')
        if annotations.get('italic'):
            marks.append('em')
        if annotations.get('underline'):
            marks.append('underline')
        if annotations.get('strikethrough'):
            marks.append('strike-through')
        if annotations.get('code'):
            marks.append('code')
        # Add more annotations if needed

        children.append({
            "_type": "span",
            "text": text.get('plain_text', ''),
            "marks": marks
        })
    return children

# %% [markdown]
# ## Convert Filtered Pages to Portable Text
# ### with JSON Log (cell #1)

# %%
# Function to convert filtered pages into Portable Text and track progress
def convert_filtered_pages_to_portable_text(filtered_pages):
    all_portable_text = []
    new_processed_pages = []

    for page in filtered_pages:
        page_id = page['id']

        # Skip if the page has already been processed
        if page_id in processed_pages:
            print(f"Page {page_id} already processed. Skipping...")
            continue

        # Fetch and parse the page content
        page_content = fetch_page_content(page_id)
        portable_text = parse_page_content_to_portable_text(page_content)

        # Include metadata properties (e.g., page title or tags)
        page_title = page['properties']['Name']['title'][0]['plain_text'] if page['properties']['Name']['title'] else "Untitled"
        metadata = {
            "title": page_title,
            "tags": [tag['name'] for tag in page['properties'].get('Tags', {}).get('multi_select', [])]
        }

        # Append converted content and metadata
        all_portable_text.append({
            "metadata": metadata,
            "content": portable_text
        })

        # Mark page as processed
        new_processed_pages.append(page_id)
        print(f"Page {page_id} processed successfully.")

    # Update the progress log with new processed pages
    with open(PROGRESS_LOG_FILE, 'w') as file:
        json.dump(processed_pages + new_processed_pages, file)

    return all_portable_text

# Convert and display filtered pages as Portable Text
portable_text_data = convert_filtered_pages_to_portable_text(filtered_pages)
print("Conversion complete.")
# Out:
# Page 14090ef7-bebc-8027-8209-ebc86820299e processed successfully.
# Conversion complete.

# %% [markdown]
# ## Convert Notion Pages to Portable Text

# %%
# Display a summary of converted pages
for page_data in portable_text_data:
    print(f"Page Title: {page_data['metadata']['title']}")
    print("Portable Text Content:")
    print(page_data['content'])
    print("\n")

# Optionally save the results to a file
with open('converted_pages.json', 'w') as output_file:
    json.dump(portable_text_data, output_file, indent=2)
    print("Converted pages saved to converted_pages.json.")
# Out:
# Page Title: Why Mastering Emotional Detachment is a Good Thing for Connection
# Portable Text Content:
# [{'_type': 'block', 'style': 'heading3', 'children': [{'_type': 'span', 'text': 'Table of Contents', 'marks': []}]}, {'_type': 'block', 'style': 'normal', 'children': [{'_type': 'span', 'text': 'David’s Philosophical Hour 🍻 “Emotional detachment” isn’t ghosting, avoiding, or manipulating—it’s maintaining your peace while being present and supportive, not using distance as a weapon.', 'marks': []}]}, {'_type': 'block', 'style': 'normal', 'children': [{'_type': 'span', 'text': 'I will educate anyone today that wants to learn… and I’ll even go as far as to say knowing what “emotional detachment” is an important aspect of how we grow a healthy relationship, and is an essential part that helps maintain individuality.', 'marks': []}]}, {'_type': 'block', 'style': 'normal', 'children': [{'_type': 'span', 'text': '🙌 Let’s talk about why controlling our emotions in relationships is so important and how it should be done.', 'marks': []}]}, {'_type': 'block', 'style': 'normal', 'children': [{'_type': 'span', 'text': 'First things first—every single one of us is unique. We all experience life differently but share some common emotional challenges.', 'marks': []}]}, {'_type': 'block', 'style': 'normal', 'children': [{'_type': 'span', 'text': 'Ever heard of the “Emotional Responsibility” formula?', 'marks': []}]}, {'_type': 'block', 'style': 'normal', 'children': [{'_type': 'span', 'text': 'We are only responsible for our own actions, words, and behaviors—not those of others. It’s impossible to control someone else, and when you try to, you unknowingly create more problems for yourself. To change this, you need to create emotional distance without building emotional walls, and learn to care without carrying the burden of what someone else does or doesn’t do. Emotional detachment is not about not caring—it’s about caring while maintaining your emotional freedom and independence.', 'marks': []}]}, {'_type': 'block', 'style': 'normal', 'children': [{'_type': 'span', 'text': '“The Distance Principle” states: The healthier your emotional boundaries, the closer you can get to others without losing yourself. Emotional detachment allows you to stay connected and supportive without being controlled by someone else’s emotional state. Keeping your attention on your own growth and well-being is essential for emotional freedom. You can’t truly have emotional freedom if your focus is always on managing others’ emotions.', 'marks': []}]}, {'_type': 'block', 'style': 'normal', 'children': [{'_type': 'span', 'text': 'Let’s be clear… mastering emotional detachment involves 3 steps, and each one is essential and skipping any step can leave you feeling insecure or dependent.', 'marks': []}]}, {'_type': 'block', 'style': 'normal', 'children': [{'_type': 'span', 'text': '1️⃣ Physical Detachment: Create physical space when\nneeded. This helps prevent reactive behavior and\ngives you the time to process your emotions.', 'marks': []}]}, {'_type': 'block', 'style': 'normal', 'children': [{'_type': 'span', 'text': '2️⃣ Mental Detachment: Redirect your thoughts and\nattention so you’re not consumed by issues. This\nmental space lets you respond thoughtfully instead\nof reacting impulsively.', 'marks': []}]}, {'_type': 'block', 'style': 'normal', 'children': [{'_type': 'span', 'text': '3️⃣ Emotional Detachment: The final level, where you\nremain emotionally independent while still caring\ndeeply. It means loving and supporting your partner\nwithout sacrificing your own emotional health.', 'marks': []}]}, {'_type': 'block', 'style': 'normal', 'children': [{'_type': 'span', 'text': 'Most people try to achieve emotional detachment without mastering physical and mental detachment first, which is like trying to swim before you can tread water. Here’s why the order matters:', 'marks': []}]}, {'_type': 'block', 'style': 'normal', 'children': [{'_type': 'span', 'text': '👏 First, you learn to float: that’s physical detachment.\n👏 Next, you learn to tread water: that’s mental de ...
#
#
# Converted pages saved to converted_pages.json.

# %% [markdown]
# ## The above data contained content [ ] so we to modify our parsing function to ensure we fetch the data appropriately
#
# ### Explanation:
#
# #### Enhanced Block Support:
# - List Items: Handles bulleted_list_item and numbered_list_item blocks, ensuring list items are parsed and included in the Portable Text output.
# - Code Blocks: Adds support for code blocks, including specifying the programming language.
# - Toggle Blocks: Adds parsing for toggle blocks, which are collapsible sections in Notion.
# Fallbacks:
# - Ensures content is only added to the portable_text list if there is rich text (rich_text) content present in the block.
#
# #### Extensibility:
#
# - Easily add more block types (e.g., quote, image, divider) as needed by extending the elif conditions.

# %%
# Function to fetch content from a Notion page, including nested blocks
def fetch_page_content(page_id):
    response = notion.blocks.children.list(page_id)
    return response['results']

# Function to convert Notion page content to Portable Text schema
def parse_page_content_to_portable_text(page_content):
    portable_text = []
    for block in page_content:
        block_type = block.get('type')

        # Parse paragraphs and headings
        if block_type in ['paragraph', 'heading_1', 'heading_2', 'heading_3']:
            style = 'normal' if block_type == 'paragraph' else block_type.replace('_', '')
            text_content = block[block_type].get('rich_text', [])
            if text_content:
                children = parse_notion_rich_text(text_content)
                portable_text.append({
                    "_type": "block",
                    "style": style,
                    "children": children
                })

        # Parse list items (bulleted or numbered)
        elif block_type in ['bulleted_list_item', 'numbered_list_item']:
            style = 'normal'
            text_content = block[block_type].get('rich_text', [])
            if text_content:
                children = parse_notion_rich_text(text_content)
                portable_text.append({
                    "_type": "block",
                    "style": style,
                    "listItem": 'bullet' if block_type == 'bulleted_list_item' else 'number',
                    "children": children
                })

        # Parse code blocks
        elif block_type == 'code':
            style = 'code'
            text_content = block[block_type].get('text', [])
            if text_content:
                children = parse_notion_rich_text(text_content)
                portable_text.append({
                    "_type": "block",
                    "style": style,
                    "children": children,
                    "codeLanguage": block[block_type].get('language', 'plaintext')
                })

        # Parse toggle blocks
        elif block_type == 'toggle':
            text_content = block[block_type].get('rich_text', [])
            if text_content:
                children = parse_notion_rich_text(text_content)
                portable_text.append({
                    "_type": "block",
                    "style": "toggle",
                    "children": children
                })

        # Handle other block types (e.g., quote, image, etc.) as needed

    return portable_text

# Function to parse Notion rich text to Portable Text format
def parse_notion_rich_text(rich_text_array):
    children = []
    for text in rich_text_array:
        marks = []
        annotations = text.get('annotations', {})
        if annotations.get('bold'):
            marks.append('strong')
        if annotations.get('italic'):
            marks.append('em')
        if annotations.get('underline'):
            marks.append('underline')
        if annotations.get('strikethrough'):
            marks.append('strike-through')
        if annotations.get('code'):
            marks.append('code')

        children.append({
            "_type": "span",
            "text": text.get('plain_text', ''),
            "marks": marks
        })
    return children

# %%
# Display a summary of converted pages
for page_data in portable_text_data:
    print(f"Page Title: {page_data['metadata']['title']}")
    print("Portable Text Content:")
    print(page_data['content'])
    print("\n")

# Optionally save the results to a file
with open('converted_pages.json', 'w') as output_file:
    json.dump(portable_text_data, output_file, indent=2)
    print("Converted pages saved to converted_pages.json.")
# Out:
# Page Title: Why Mastering Emotional Detachment is a Good Thing for Connection
# Portable Text Content:
# [{'_type': 'block', 'style': 'heading3', 'children': [{'_type': 'span', 'text': 'Table of Contents', 'marks': []}]}, {'_type': 'block', 'style': 'normal', 'children': [{'_type': 'span', 'text': 'David’s Philosophical Hour 🍻 “Emotional detachment” isn’t ghosting, avoiding, or manipulating—it’s maintaining your peace while being present and supportive, not using distance as a weapon.', 'marks': []}]}, {'_type': 'block', 'style': 'normal', 'children': [{'_type': 'span', 'text': 'I will educate anyone today that wants to learn… and I’ll even go as far as to say knowing what “emotional detachment” is an important aspect of how we grow a healthy relationship, and is an essential part that helps maintain individuality.', 'marks': []}]}, {'_type': 'block', 'style': 'normal', 'children': [{'_type': 'span', 'text': '🙌 Let’s talk about why controlling our emotions in relationships is so important and how it should be done.', 'marks': []}]}, {'_type': 'block', 'style': 'normal', 'children': [{'_type': 'span', 'text': 'First things first—every single one of us is unique. We all experience life differently but share some common emotional challenges.', 'marks': []}]}, {'_type': 'block', 'style': 'normal', 'children': [{'_type': 'span', 'text': 'Ever heard of the “Emotional Responsibility” formula?', 'marks': []}]}, {'_type': 'block', 'style': 'normal', 'children': [{'_type': 'span', 'text': 'We are only responsible for our own actions, words, and behaviors—not those of others. It’s impossible to control someone else, and when you try to, you unknowingly create more problems for yourself. To change this, you need to create emotional distance without building emotional walls, and learn to care without carrying the burden of what someone else does or doesn’t do. Emotional detachment is not about not caring—it’s about caring while maintaining your emotional freedom and independence.', 'marks': []}]}, {'_type': 'block', 'style': 'normal', 'children': [{'_type': 'span', 'text': '“The Distance Principle” states: The healthier your emotional boundaries, the closer you can get to others without losing yourself. Emotional detachment allows you to stay connected and supportive without being controlled by someone else’s emotional state. Keeping your attention on your own growth and well-being is essential for emotional freedom. You can’t truly have emotional freedom if your focus is always on managing others’ emotions.', 'marks': []}]}, {'_type': 'block', 'style': 'normal', 'children': [{'_type': 'span', 'text': 'Let’s be clear… mastering emotional detachment involves 3 steps, and each one is essential and skipping any step can leave you feeling insecure or dependent.', 'marks': []}]}, {'_type': 'block', 'style': 'normal', 'children': [{'_type': 'span', 'text': '1️⃣ Physical Detachment: Create physical space when\nneeded. This helps prevent reactive behavior and\ngives you the time to process your emotions.', 'marks': []}]}, {'_type': 'block', 'style': 'normal', 'children': [{'_type': 'span', 'text': '2️⃣ Mental Detachment: Redirect your thoughts and\nattention so you’re not consumed by issues. This\nmental space lets you respond thoughtfully instead\nof reacting impulsively.', 'marks': []}]}, {'_type': 'block', 'style': 'normal', 'children': [{'_type': 'span', 'text': '3️⃣ Emotional Detachment: The final level, where you\nremain emotionally independent while still caring\ndeeply. It means loving and supporting your partner\nwithout sacrificing your own emotional health.', 'marks': []}]}, {'_type': 'block', 'style': 'normal', 'children': [{'_type': 'span', 'text': 'Most people try to achieve emotional detachment without mastering physical and mental detachment first, which is like trying to swim before you can tread water. Here’s why the order matters:', 'marks': []}]}, {'_type': 'block', 'style': 'normal', 'children': [{'_type': 'span', 'text': '👏 First, you learn to float: that’s physical detachment.\n👏 Next, you learn to tread water: that’s mental de ...
#
#
# Converted pages saved to converted_pages.json.

# %% [markdown]
# ### Debug
# If you still encounter issues with empty content, print the page_content to inspect the exact structure returned by the Notion API:

# %%
print(json.dumps(page_content, indent=2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-e74548b72ea2> in <module>
# ----> 1 print(json.dumps(page_content, indent=2))
#
# NameError: name 'page_content' is not defined
